# %%
import vizdoom as vzd
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
game = vzd.DoomGame()
game.load_config('resources/temp_maps/datagen.cfg')
game.set_doom_scenario_path('data/mazemaker_maps/15x15.wad')
game.set_mode(vzd.Mode.SPECTATOR)
game.init()
game.new_episode()

# %%
game = vzd.DoomGame()
game.load_config('resources/temp_maps/datagen.cfg')
game.set_doom_scenario_path('data/mazemaker_maps/15x15.wad')
game.set_automap_mode(vzd.AutomapMode.WHOLE)
game.set_objects_info_enabled(True)
game.set_labels_buffer_enabled(True)
game.init()
game.new_episode()
game.make_action([1,0,0,0])
state = game.get_state()
am = state.automap_buffer.transpose(1,2,0)
obj = state.objects
labels = state.labels
game.close()
print(state.game_variables)
plt.imshow(am)
# Out:
# [1476.39877319  868.78248596    0.           60.68298341]

# %%
print(len(obj))
for i in range(len(obj)):
    print(f'{obj[i].name}: x={obj[i].position_x}, y={obj[i].position_y}, z={obj[i].position_z}, angle={obj[i].angle}')
# Out:
# 102
# Stimpack: x=-96.0, y=32.0, z=0.0, angle=0.0
# Stimpack: x=-160.0, y=32.0, z=0.0, angle=0.0
# DoomPlayer: x=-192.0, y=-160.0, z=0.0, angle=0.0
# Stalagtite: x=1488.0, y=1344.0, z=144.0, angle=0.0
# TorchTree: x=1488.0, y=1280.0, z=144.0, angle=0.0
# TorchTree: x=1536.0, y=1216.0, z=144.0, angle=0.0
# Stalagtite: x=1568.0, y=1280.0, z=144.0, angle=0.0
# TorchTree: x=1664.0, y=1248.0, z=144.0, angle=0.0
# TorchTree: x=1584.0, y=1360.0, z=144.0, angle=0.0
# Column: x=1664.0, y=-1056.0, z=-96.0, angle=0.0
# Shell: x=1240.0, y=-968.0, z=-96.0, angle=0.0
# Zombieman: x=1392.0, y=-160.0, z=-64.0, angle=0.0
# ArmorBonus: x=456.0, y=112.0, z=-32.0, angle=0.0
# ArmorBonus: x=456.0, y=176.0, z=-32.0, angle=0.0
# HealthBonus: x=248.0, y=176.0, z=-32.0, angle=0.0
# HealthBonus: x=248.0, y=112.0, z=-32.0, angle=0.0
# Zombieman: x=416.0, y=176.0, z=-64.0, angle=45.00000001047738
# Zombieman: x=352.0, y=224.0, z=-64.0, angle=90.00000002095476
# ExplosiveBarrel: x=864.0, y=88.0, z=-64.0, angle=0.0
# ExplosiveBarrel: x=1264.0, y=-32.0, z=-64.0, angle=180.00000004190952
# ExplosiveBarrel: x=912.0, y=24.0, z=-64.0, angle=0.0
# ExplosiveBarrel: x=872.0, y=40.0, z=-64.0, angle=0.0
# ExplosiveBarrel: x=1240.0, y=-72.0, z=-64.0, angle=180.00000004190952
# ArmorBonus: x=976.0, y=-208.0, z=-128.0, angle=0.0
# ArmorBonus: x=976.0, y=-160.0, z=-128.0, angle=0.0
# ArmorBonus: x=976.0, y=-112.0, z=-128.0, angle=0.0
# ArmorBonus: x=976.0, y=-256.0, z=-128.0, angle=0.0
# HealthBonus: x=1200.0, y=-112.0, z=-128.0, angle=0.0
# HealthBonus: x=1200.0, y=-160.0, z=-128.0, angle=0.0
# HealthBonus: x=1200.0, y=-208.0, z=-128.0, angle=0.0
# HealthBonus: x=1200.0, y=-256.0, z=-128.0, angle=0.0
# Medikit: x=1088.0, y=-192.0, z=-128.0, angle=0.0
# Clip: x=600.0, y=128.0, z=-64.0, angle=0.0
# Zombieman: x=704.0, y=64.0, z=-64.0, angle=0.0
# Column: x=680.0, y=128.0, z=-44.0, angle=0.0
# Clip: x=1576.0, y=128.0, z=-64.0, angle=0.0
# Column: x=1496.0, y=128.0, z=-44.0, angle=0.0
# Zombieman: x=1024.0, y=328.0, z=-64.0, angle=270.0000000628643
# GreenArmor: x=1088.0, y=352.0, z=-49.0, angle=0.0
# Stimpack: x=1088.0, y=296.0, z=-64.0, angle=0.0
# Clip: x=-96.0, y=-864.0, z=-96.0, angle=0.0
# Clip: x=-80.0, y=-816.0, z=-96.0, angle=0.0
# ShotgunGuy: x=512.0, y=-1024.0, z=-96.0, angle=0.0
# ShotgunGuy: x=1952.0, y=48.0, z=16.0, angle=270.0000000628643
# Stimpack: x=2096.0, y=-96.0, z=48.0, angle=0.0
# ClipBox: x=2096.0, y=-160.0, z=48.0, angle=0.0
# TechPillar: x=1952.0, y=-32.0, z=16.0, angle=270.0000000628643
# TorchTree: x=720.0, y=1024.0, z=56.0, angle=0.0
# TorchTree: x=920.0, y=1448.0, z=168.0, angle=0.0
# BigTree: x=904.0, y=1560.0, z=168.0, angle=0.0
# TorchTree: x=800.0, y=1568.0, z=168.0, angle=0.0
# TorchTree: x=752.0, y=1456.0, z=168.0, angle=0.0
# BigTree: x=832.0, y=1472.0, z=168.0, angle=0.0
# Stimpack: x=1816.0, y=-728.0, z=16.0, angle=0.0
# Clip: x=1824.0, y=-680.0, z=16.0, angle=0.0
# HealthBonus: x=1792.0, y=-960.0, z=16.0, angle=0.0
# HealthBonus: x=1856.0, y=-960.0, z=16.0, angle=0.0
# HealthBonus: x=1920.0, y=-960.0, z=16.0, angle=0.0
# ArmorBonus: x=2064.0, y=-736.0, z=16.0, angle=0.0
# ArmorBonus: x=2064.0, y=-800.0, z=16.0, angle=0.0
# ShotgunGuy: x=1752.0, y=-936.0, z=16.0, angle=0.0
# Zombieman: x=1952.0, y=-536.0, z=16.0, angle=90.00000002095476
# Shell: x=2016.0, y=-928.0, z=32.0, angle=0.0
# Shotgun: x=1536.0, y=-160.0, z=16.0, angle=0.0
# Shell: x=1672.0, y=-664.0, z=-128.0, angle=0.0
# Clip: x=1088.0, y=-416.0, z=-80.0, angle=0.0
# DoomImp: x=-48.0, y=-1088.0, z=-96.0, angle=0.0
# Zombieman: x=664.0, y=-536.0, z=-160.0, angle=315.00000007334165
# ExplosiveBarrel: x=704.0, y=-688.0, z=-160.0, angle=0.0
# DoomImp: x=1328.0, y=-432.0, z=-64.0, angle=270.0000000628643
# Soulsphere: x=880.0, y=1064.0, z=40.0, angle=0.0
# TorchTree: x=1440.0, y=1104.0, z=56.0, angle=0.0
# BigTree: x=1288.0, y=1192.0, z=56.0, angle=0.0
# BigTree: x=800.0, y=832.0, z=56.0, angle=0.0
# TorchTree: x=1440.0, y=808.0, z=56.0, angle=0.0
# BigTree: x=1344.0, y=880.0, z=56.0, angle=0.0
# TorchTree: x=1264.0, y=912.0, z=56.0, angle=0.0
# Stalagtite: x=1088.0, y=1008.0, z=56.0, angle=0.0
# BigTree: x=1376.0, y=1168.0, z=56.0, angle=0.0
# BigTree: x=872.0, y=904.0, z=56.0, angle=0.0
# Zombieman: x=960.0, y=744.0, z=104.0, angle=0.0
# Zombieman: x=912.0, y=784.0, z=104.0, angle=0.0
# Column: x=96.0, y=-1280.0, z=-128.0, angle=180.00000004190952
# Column: x=352.0, y=-1280.0, z=-128.0, angle=180.00000004190952
# Chainsaw: x=1320.0, y=688.0, z=136.0, angle=0.0
# TorchTree: x=1104.0, y=1296.0, z=56.0, angle=0.0
# Stimpack: x=-192.0, y=-1024.0, z=-96.0, angle=0.0
# ArmorBonus: x=-192.0, y=-992.0, z=-96.0, angle=0.0
# ArmorBonus: x=-192.0, y=-960.0, z=-96.0, angle=0.0
# ArmorBonus: x=-192.0, y=-1120.0, z=-96.0, angle=0.0
# ArmorBonus: x=-192.0, y=-1088.0, z=-96.0, angle=0.0
# ArmorBonus: x=-192.0, y=-1056.0, z=-96.0, angle=0.0
# ArmorBonus: x=-192.0, y=-928.0, z=-96.0, angle=0.0
# DoomImp: x=1504.0, y=-440.0, z=-96.0, angle=270.0000000628643
# Stimpack: x=1040.0, y=-736.0, z=-144.0, angle=0.0
# Stimpack: x=992.0, y=-768.0, z=-144.0, angle=0.0
# BlueArmor: x=472.0, y=-1344.0, z=-80.0, angle=0.0
# Stalagtite: x=736.0, y=872.0, z=56.0, angle=0.0
# Stalagtite: x=1256.0, y=1256.0, z=56.0, angle=0.0
# Stalagtite: x=1504.0, y=1088.0, z=56.0, angle=0.0
# Stalagtite: x=960.0, y=1184.0, z=56.0, angle=0.0
# TorchTree: x=1040.0, y=1232.0, z=56.0, angle=0.0

# %%
print(len(labels))
for i in range(len(labels)):
    print(f'{labels[i].object_name}: x={labels[i].object_position_x}, y={labels[i].object_position_y}, z={labels[i].object_position_z}, angle={labels[i].object_angle}')
# Out:
# 1
# DoomPlayer: x=-192.0, y=-160.0, z=0.0, angle=0.0
